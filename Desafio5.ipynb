# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats as st
from sklearn.decomposition import PCA

# %%
from loguru import logger

# %%
# Algumas configurações para o matplotlib.
#%matplotlib inline

from IPython.core.pylabtools import figsize


figsize(12, 8)

sns.set()

# %%
fifa = pd.read_csv("fifa.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    fifa.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
# Sua análise começa aqui.
fifa.head()
# Out:
#    Age  Overall  Potential  Crossing  Finishing  HeadingAccuracy  \
# 0   31       94         94      84.0       95.0             70.0
# 1   33       94         94      84.0       94.0             89.0
# 2   26       92         93      79.0       87.0             62.0
# 3   27       91         93      17.0       13.0             21.0
# 4   27       91         92      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  Penalties  Composure  \
# 0          90.0     86.0       97.0   93.0  ...       75.0       96.0
# 1          81.0     87.0       88.0   81.0  ...       85.0       95.0
# 2          84.0     84.0       96.0   88.0  ...       81.0       94.0
# 3          50.0     13.0       18.0   21.0  ...       40.0       68.0
# 4          92.0     82.0       86.0   85.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 37 columns]

# %%
cons = pd.DataFrame({'colunas' : fifa.columns,
                    'tipo': fifa.dtypes,
                    'missing' : fifa.isna().sum(),
                    'size' : fifa.shape[0],
                    'unicos': fifa.nunique()})
cons['percentual'] = round(cons['missing'] / cons['size'],3)
cons
# Out:
#                          colunas     tipo  missing   size  unicos  percentual
# Age                          Age    int64        0  18207      29       0.000
# Overall                  Overall    int64        0  18207      48       0.000
# Potential              Potential    int64        0  18207      47       0.000
# Crossing                Crossing  float64       48  18207      89       0.003
# Finishing              Finishing  float64       48  18207      93       0.003
# HeadingAccuracy  HeadingAccuracy  float64       48  18207      91       0.003
# ShortPassing        ShortPassing  float64       48  18207      85       0.003
# Volleys                  Volleys  float64       48  18207      87       0.003
# Dribbling              Dribbling  float64       48  18207      94       0.003
# Curve                      Curve  float64       48  18207      89       0.003
# FKAccuracy            FKAccuracy  float64       48  18207      90       0.003
# LongPassing          LongPassing  float64       48  18207      84       0.003
# BallControl          BallControl  float64       48  18207      90       0.003
# Acceleration        Acceleration  float64       48  18207      86       0.003
# SprintSpeed          SprintSpeed  float64       48  18207      85       0.003
# Agility                  Agility  float64       48  18207      81       0.003
# Reactions              Reactions  float64       48  18207      68       0.003
# Balance                  Balance  float64       48  18207      81       0.003
# ShotPower              ShotPower  float64       48  18207      92       0.003
# Jumping                  Jumping  float64       48  18207      74       0.003
# Stamina                  Stamina  float64       48  18207      85       0.003
# Strength                Strength  float64       48  18207      74       0.003
# LongShots              LongShots  float64       48  18207      92       0.003
# Aggression            Aggression  float64       48  18207      85       0.003
# Interceptions      Interceptions  float64       48  18207      89       0.003
# Positioning          Positioning  float64       48  18207      94       0.003
# Vision                    Vision  float64       48  18207      85       0.003
# Penalties              Penalties  float64       48  18207      87       0.003
# Composure              Composure  float64       48  18207      84       0.003
# Marking                  Marking  float64       48  18207      92       0.003
# StandingTackle    StandingTackle  float64       48  18207      90       0.003
# SlidingTackle      SlidingTackle  float64       48  18207      88       0.003
# GKDiving                GKDiving  float64       48  18207      71       0.003
# GKHandling            GKHandling  float64       48  18207      70       0.003
# GKKicking              GKKicking  float64       48  18207      79       0.003
# GKPositioning      GKPositioning  float64       48  18207      79       0.003
# GKReflexes            GKReflexes  float64       48  18207      76       0.003

# %%
fifa.dropna(inplace =True)
fifa.shape
# Out:
# (18159, 37)

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
def q1():
    pca = PCA(n_components=1)
    pca.fit(fifa)
    evr = pca.explained_variance_ratio_
    return round(float(evr),3)
q1()
# Out:
# 0.565

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
def q2():
    pca_095 = PCA(n_components = 0.95)
    fifa_reduced = pca_095.fit_transform(fifa)
    return fifa_reduced.shape[1]
q2()
# Out:
# 15

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %%
def q3():
    pca = PCA(n_components=2)
    pca.fit(fifa)
    matriz = pca.components_
    return tuple(matriz.dot(x).round(3))
q3()
# Out:
# (186.556, -6.592)

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
def q4():
    x_fifa = fifa.drop('Overall', axis=1)
    y_fifa = fifa['Overall']
    estimador = LinearRegression()
    estimador.fit(x_fifa, y_fifa)
    seletor = RFE(estimator = estimador, n_features_to_select=5, step=1)
    seletor.fit(x_fifa, y_fifa)
    return list(x_fifa.columns[seletor.support_])
q4()
# Out:
# ['Age', 'Potential', 'BallControl', 'Reactions', 'GKReflexes']
